# %%
# hasthags indicate notes about code; the code below imports a few packages we will need for this analysis
import pandas as pd
# import statsmodels.api as sm
# import pylab as pl
import numpy as np


# %matplotlib notebook

# %%
# read the data in
df = pd.read_csv("binary.csv")

# %%
print(df.head())

df.columns = ["admit", "gre", "gpa", "prestige"]
df.columns

print(df.describe())

# take a look at the standard deviation of each column
df.std()

# frequency table cutting presitge and whether or not someone was admitted
pd.crosstab(df['admit'], df['prestige'], rownames=['admit'])

df.hist()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4
#             admit         gre         gpa   prestige
# count  400.000000  400.000000  400.000000  400.00000
# mean     0.317500  587.700000    3.389900    2.48500
# std      0.466087  115.516536    0.380567    0.94446
# min      0.000000  220.000000    2.260000    1.00000
# 25%      0.000000  520.000000    3.130000    2.00000
# 50%      0.000000  580.000000    3.395000    2.00000
# 75%      1.000000  660.000000    3.670000    3.00000
# max      1.000000  800.000000    4.000000    4.00000
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000085C2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000860E7B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008635E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000008694518>]], dtype=object)
